# %% [markdown]
# ROBÔ PARA DOWNLOAD DOS DADOS DA CVM
#
# REGRA DE NEGÓCIO ATUALIZADA:
# - Para arquivos históricos, o download é pulado se o arquivo já existir.
# - Para o arquivo do MÊS CORRENTE, o download é sempre forçado para garantir
#   a versão mais recente, substituindo o arquivo local se ele existir.

# %%
import logging
import time
from datetime import datetime
from pathlib import Path
import requests
import zipfile

# --- CONFIGURAÇÃO CENTRAL ---
CONFIG = {
    "PASTA_DOWNLOAD_RAW": Path("01_downloads_raw_zips"),
    "PASTA_DADOS_EXTRAIDOS": Path("02_dados_extraidos_csv"),
    "URL_BASE_ANUAIS": "http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/HIST/",
    "NOME_ARQUIVO_ANUAL": "inf_diario_fi_{ano:04d}.zip",
    "ANO_INICIAL_HISTORICO": 2000,
    "ANO_FINAL_HISTORICO": 2021,
    "URL_BASE_MENSAIS": "http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/",
    "NOME_ARQUIVO_MENSAL": "inf_diario_fi_{ano:04d}{mes:02d}.zip",
    "ANO_INICIAL_MENSAL": 2021,
    "PAUSA_REQUISICOES_SEG": 1.0,
    "USER_AGENT": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
}

# --- Configuração do Logging ---
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)


def criar_pastas_necessarias():
    logging.info("Verificando e criando pastas de trabalho...")
    CONFIG["PASTA_DOWNLOAD_RAW"].mkdir(parents=True, exist_ok=True)
    CONFIG["PASTA_DADOS_EXTRAIDOS"].mkdir(parents=True, exist_ok=True)


def baixar_arquivo(session: requests.Session, url: str, caminho_salvar: Path) -> bool:
    if caminho_salvar.exists():
        logging.info(f"Arquivo já existe, pulando: {caminho_salvar.name}")
        return True
    try:
        logging.info(f"Baixando: {url}")
        with session.get(url, stream=True, timeout=60) as r:
            if r.status_code == 404:
                logging.warning(f"Arquivo não encontrado (404): {url}")
                return False
            r.raise_for_status()
            with open(caminho_salvar, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
            logging.info(f"Salvo com sucesso: {caminho_salvar.name}")
            return True
    except requests.exceptions.RequestException as e:
        logging.error(f"Falha ao baixar {url}: {e}")
        return False


def baixar_dados_anuais(session: requests.Session):
    logging.info("--- INICIANDO DOWNLOAD DOS DADOS ANUAIS HISTÓRICOS ---")
    ano_inicial = CONFIG["ANO_INICIAL_HISTORICO"]
    ano_final = CONFIG["ANO_FINAL_HISTORICO"]
    for ano in range(ano_final, ano_inicial - 1, -1):
        nome_arquivo = CONFIG["NOME_ARQUIVO_ANUAL"].format(ano=ano)
        url_completa = CONFIG["URL_BASE_ANUAIS"] + nome_arquivo
        caminho_salvar = CONFIG["PASTA_DOWNLOAD_RAW"] / nome_arquivo
        baixar_arquivo(session, url_completa, caminho_salvar)
        time.sleep(CONFIG["PAUSA_REQUISICOES_SEG"])


# <<< INÍCIO DA ALTERAÇÃO >>>
def baixar_dados_mensais(session: requests.Session):
    """
    Baixa os arquivos mensais.
    Força o download para o mês corrente (M) e o mês anterior (M-1),
    removendo os arquivos locais se eles existirem.
    """
    logging.info("--- INICIANDO DOWNLOAD DOS DADOS MENSAIS RECENTES ---")
    try:
        from dateutil.relativedelta import relativedelta
    except ImportError:
        logging.error("Biblioteca 'python-dateutil' não encontrada. Instale com: pip install python-dateutil")
        return
        
    hoje = datetime.now()
    mes_anterior = hoje - relativedelta(months=1) # Calcula o mês anterior
    data_inicio_busca = datetime(CONFIG["ANO_INICIAL_MENSAL"], 1, 1)
    
    data_corrente_loop = hoje
    while data_corrente_loop >= data_inicio_busca:
        nome_arquivo = CONFIG["NOME_ARQUIVO_MENSAL"].format(ano=data_corrente_loop.year, mes=data_corrente_loop.month)
        caminho_salvar = CONFIG["PASTA_DOWNLOAD_RAW"] / nome_arquivo
        url_completa = CONFIG["URL_BASE_MENSAIS"] + nome_arquivo

        # Verifica se o arquivo em questão é do mês corrente (M)
        eh_mes_corrente = (data_corrente_loop.year == hoje.year and 
                           data_corrente_loop.month == hoje.month)
        
        # Verifica se o arquivo em questão é do mês anterior (M-1)
        eh_mes_anterior = (data_corrente_loop.year == mes_anterior.year and 
                           data_corrente_loop.month == mes_anterior.month)

        # Se for M ou M-1 e o arquivo já existir, remove para forçar o download
        if (eh_mes_corrente or eh_mes_anterior) and caminho_salvar.exists():
            logging.info(f"Arquivo de atualização frequente (M ou M-1). Removendo versão antiga: {caminho_salvar.name}")
            caminho_salvar.unlink()

        baixar_arquivo(session, url_completa, caminho_salvar)
        
        data_corrente_loop -= relativedelta(months=1)
        time.sleep(CONFIG["PAUSA_REQUISICOES_SEG"])
# <<< FIM DA ALTERAÇÃO >>>


def extrair_arquivos_zip():
    logging.info("--- INICIANDO EXTRAÇÃO DOS ARQUIVOS .ZIP ---")
    pasta_raw = CONFIG["PASTA_DOWNLOAD_RAW"]
    pasta_extraidos = CONFIG["PASTA_DADOS_EXTRAIDOS"]
    logging.info(f"Limpando pasta de destino antes da extração: '{pasta_extraidos}'")
    for arquivo_antigo in pasta_extraidos.glob("*"):
        try:
            if arquivo_antigo.is_file():
                arquivo_antigo.unlink()
        except Exception as e:
            logging.error(f"Não foi possível remover o arquivo antigo {arquivo_antigo.name}: {e}")
    arquivos_zip = list(pasta_raw.glob("*.zip"))
    if not arquivos_zip:
        logging.warning("Nenhum arquivo .zip encontrado na pasta de downloads para extrair.")
        return
    logging.info(f"Encontrados {len(arquivos_zip)} arquivos .zip para processar.")
    for caminho_zip in arquivos_zip:
        logging.info(f"Extraindo: {caminho_zip.name} -> para '{pasta_extraidos}'")
        try:
            with zipfile.ZipFile(caminho_zip, 'r') as zip_ref:
                zip_ref.extractall(pasta_extraidos)
        except zipfile.BadZipFile:
            logging.error(f"Erro: O arquivo {caminho_zip.name} parece estar corrompido ou não é um .zip válido.")
        except Exception as e:
            logging.error(f"Falha inesperada ao extrair {caminho_zip.name}: {e}")
    logging.info("--- Processo de extração concluído. A pasta de destino foi reconstruída. ---")


def main():
    """Função principal que orquestra todo o processo."""
    logging.info(">>> INICIANDO ROTINA DE CARGA TOTAL DE DADOS DE FUNDOS CVM <<<")
    criar_pastas_necessarias()
    headers = {'User-Agent': CONFIG['USER_AGENT']}
    with requests.Session() as session:
        session.headers.update(headers)
        baixar_dados_anuais(session)
        baixar_dados_mensais(session)
    extrair_arquivos_zip()
    logging.info(">>> ROTINA FINALIZADA COM SUCESSO! <<<")


if __name__ == "__main__":
    main()
# Out:
# 2025-08-03 19:51:20 [INFO] - >>> INICIANDO ROTINA DE CARGA TOTAL DE DADOS DE FUNDOS CVM <<<
# 2025-08-03 19:51:20 [INFO] - Verificando e criando pastas de trabalho...
# 2025-08-03 19:51:20 [INFO] - --- INICIANDO DOWNLOAD DOS DADOS ANUAIS HISTÓRICOS ---
# 2025-08-03 19:51:20 [INFO] - Baixando: http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/HIST/inf_diario_fi_2021.zip
# 2025-08-03 19:51:20 [WARNING] - Arquivo não encontrado (404): http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/HIST/inf_diario_fi_2021.zip
# 2025-08-03 19:51:21 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2020.zip
# 2025-08-03 19:51:22 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2019.zip
# 2025-08-03 19:51:23 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2018.zip
# 2025-08-03 19:51:24 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2017.zip
# 2025-08-03 19:51:25 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2016.zip
# 2025-08-03 19:51:26 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2015.zip
# 2025-08-03 19:51:27 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2014.zip
# 2025-08-03 19:51:28 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2013.zip
# 2025-08-03 19:51:29 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2012.zip
# 2025-08-03 19:51:30 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2011.zip
# 2025-08-03 19:51:31 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2010.zip
# 2025-08-03 19:51:32 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2009.zip
# 2025-08-03 19:51:33 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2008.zip
# 2025-08-03 19:51:34 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2007.zip
# 2025-08-03 19:51:35 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2006.zip
# 2025-08-03 19:51:36 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2005.zip
# 2025-08-03 19:51:37 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2004.zip
# 2025-08-03 19:51:38 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2003.zip
# 2025-08-03 19:51:39 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2002.zip
# 2025-08-03 19:51:40 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2001.zip
# 2025-08-03 19:51:41 [INFO] - Arquivo já existe, pulando: inf_diario_fi_2000.zip
# 2025-08-03 19:51:42 [INFO] - --- INICIANDO DOWNLOAD DOS DADOS MENSAIS RECENTES ---
# 2025-08-03 19:51:42 [INFO] - Arquivo de atualização frequente (M ou M-1). Removendo versão antiga: inf_diario_fi_202508.zip
# 2025-08-03 19:51:42 [INFO] - Baixando: http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_202508.zip
# 2025-08-03 19:51:42 [INFO] - Salvo com sucesso: inf_diario_fi_202508.zip
# 2025-08-03 19:51:43 [INFO] - Arquivo de atualização frequente (M ou M-1). Removendo versão antiga: inf_diario_fi_202507.zip
# 2025-08-03 19:51:43 [INFO] - Baixando: http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_202507.zip
# 2025-08-03 19:51:49 [INFO] - Salvo com sucesso: inf_diario_fi_202507.zip
# 2025-08-03 19:51:50 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202506.zip
# 2025-08-03 19:51:51 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202505.zip
# 2025-08-03 19:51:52 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202504.zip
# 2025-08-03 19:51:53 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202503.zip
# 2025-08-03 19:51:54 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202502.zip
# 2025-08-03 19:51:55 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202501.zip
# 2025-08-03 19:51:56 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202412.zip
# 2025-08-03 19:51:57 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202411.zip
# 2025-08-03 19:51:58 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202410.zip
# 2025-08-03 19:51:59 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202409.zip
# 2025-08-03 19:52:00 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202408.zip
# 2025-08-03 19:52:01 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202407.zip
# 2025-08-03 19:52:02 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202406.zip
# 2025-08-03 19:52:03 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202405.zip
# 2025-08-03 19:52:04 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202404.zip
# 2025-08-03 19:52:05 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202403.zip
# 2025-08-03 19:52:06 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202402.zip
# 2025-08-03 19:52:07 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202401.zip
# 2025-08-03 19:52:08 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202312.zip
# 2025-08-03 19:52:09 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202311.zip
# 2025-08-03 19:52:10 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202310.zip
# 2025-08-03 19:52:11 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202309.zip
# 2025-08-03 19:52:12 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202308.zip
# 2025-08-03 19:52:13 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202307.zip
# 2025-08-03 19:52:14 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202306.zip
# 2025-08-03 19:52:15 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202305.zip
# 2025-08-03 19:52:16 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202304.zip
# 2025-08-03 19:52:17 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202303.zip
# 2025-08-03 19:52:18 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202302.zip
# 2025-08-03 19:52:19 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202301.zip
# 2025-08-03 19:52:20 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202212.zip
# 2025-08-03 19:52:21 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202211.zip
# 2025-08-03 19:52:22 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202210.zip
# 2025-08-03 19:52:23 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202209.zip
# 2025-08-03 19:52:24 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202208.zip
# 2025-08-03 19:52:25 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202207.zip
# 2025-08-03 19:52:26 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202206.zip
# 2025-08-03 19:52:27 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202205.zip
# 2025-08-03 19:52:28 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202204.zip
# 2025-08-03 19:52:29 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202203.zip
# 2025-08-03 19:52:30 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202202.zip
# 2025-08-03 19:52:31 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202201.zip
# 2025-08-03 19:52:32 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202112.zip
# 2025-08-03 19:52:33 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202111.zip
# 2025-08-03 19:52:34 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202110.zip
# 2025-08-03 19:52:35 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202109.zip
# 2025-08-03 19:52:36 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202108.zip
# 2025-08-03 19:52:37 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202107.zip
# 2025-08-03 19:52:38 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202106.zip
# 2025-08-03 19:52:39 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202105.zip
# 2025-08-03 19:52:40 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202104.zip
# 2025-08-03 19:52:41 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202103.zip
# 2025-08-03 19:52:42 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202102.zip
# 2025-08-03 19:52:43 [INFO] - Arquivo já existe, pulando: inf_diario_fi_202101.zip
# 2025-08-03 19:52:44 [INFO] - --- INICIANDO EXTRAÇÃO DOS ARQUIVOS .ZIP ---
# 2025-08-03 19:52:44 [INFO] - Limpando pasta de destino antes da extração: '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Encontrados 77 arquivos .zip para processar.
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2000.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2001.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2002.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2003.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2004.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2005.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:44 [INFO] - Extraindo: inf_diario_fi_2006.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:45 [INFO] - Extraindo: inf_diario_fi_2007.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:45 [INFO] - Extraindo: inf_diario_fi_2008.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:46 [INFO] - Extraindo: inf_diario_fi_2009.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:47 [INFO] - Extraindo: inf_diario_fi_2010.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:47 [INFO] - Extraindo: inf_diario_fi_2011.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:48 [INFO] - Extraindo: inf_diario_fi_2012.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:49 [INFO] - Extraindo: inf_diario_fi_2013.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:50 [INFO] - Extraindo: inf_diario_fi_2014.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:51 [INFO] - Extraindo: inf_diario_fi_2015.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:52 [INFO] - Extraindo: inf_diario_fi_2016.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:53 [INFO] - Extraindo: inf_diario_fi_2017.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:54 [INFO] - Extraindo: inf_diario_fi_2018.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:55 [INFO] - Extraindo: inf_diario_fi_2019.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:56 [INFO] - Extraindo: inf_diario_fi_2020.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:57 [INFO] - Extraindo: inf_diario_fi_202101.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:57 [INFO] - Extraindo: inf_diario_fi_202102.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:57 [INFO] - Extraindo: inf_diario_fi_202103.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202104.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202105.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202106.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202107.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202108.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202109.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:58 [INFO] - Extraindo: inf_diario_fi_202110.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202111.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202112.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202201.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202202.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202203.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202204.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:52:59 [INFO] - Extraindo: inf_diario_fi_202205.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202206.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202207.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202208.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202209.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202210.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:00 [INFO] - Extraindo: inf_diario_fi_202211.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202212.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202301.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202302.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202303.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202304.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202305.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:01 [INFO] - Extraindo: inf_diario_fi_202306.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202307.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202308.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202309.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202310.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202311.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:02 [INFO] - Extraindo: inf_diario_fi_202312.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:03 [INFO] - Extraindo: inf_diario_fi_202401.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:03 [INFO] - Extraindo: inf_diario_fi_202402.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:03 [INFO] - Extraindo: inf_diario_fi_202403.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:15 [INFO] - Extraindo: inf_diario_fi_202404.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:15 [INFO] - Extraindo: inf_diario_fi_202405.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:15 [INFO] - Extraindo: inf_diario_fi_202406.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:15 [INFO] - Extraindo: inf_diario_fi_202407.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:15 [INFO] - Extraindo: inf_diario_fi_202408.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:16 [INFO] - Extraindo: inf_diario_fi_202409.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:16 [INFO] - Extraindo: inf_diario_fi_202410.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:16 [INFO] - Extraindo: inf_diario_fi_202411.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:16 [INFO] - Extraindo: inf_diario_fi_202412.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:16 [INFO] - Extraindo: inf_diario_fi_202501.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:17 [INFO] - Extraindo: inf_diario_fi_202502.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:17 [INFO] - Extraindo: inf_diario_fi_202503.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:17 [INFO] - Extraindo: inf_diario_fi_202504.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:17 [INFO] - Extraindo: inf_diario_fi_202505.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:17 [INFO] - Extraindo: inf_diario_fi_202506.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:18 [INFO] - Extraindo: inf_diario_fi_202507.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:18 [INFO] - Extraindo: inf_diario_fi_202508.zip -> para '02_dados_extraidos_csv'
# 2025-08-03 19:53:18 [INFO] - --- Processo de extração concluído. A pasta de destino foi reconstruída. ---
# 2025-08-03 19:53:18 [INFO] - >>> ROTINA FINALIZADA COM SUCESSO! <<<
